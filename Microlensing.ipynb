# %%
from astropy.table import Table
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'G:\My Drive\table5.tex', skiprows=48, sep='&', usecols=(0, 1, 2), skipfooter=6, names=("Name", "RA", "Dec"))
df
# Out:
# C:\Users\judah\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                  Name          RA              Dec
# 0   WISE 0146+4234      26.735579      42.569408
# 1   WISE 0336$-$0143    54.020862    $-$1.732170
# 2   WISE 0350$-$5658    57.500996    $-$56.975638
# 3   WISE 0359$-$5401    59.891827    $-$54.032517
# 4   WISE 0410+1502      62.595853      15.044417
# 5   WISE 0535$-$7500    83.819477    $-$75.006740
# 6   WISE 0647$-$6232   101.846784    $-$62.542832
# 7   WISE 0713$-$2917   108.344414    $-$29.298188
# 8   WISE 0734$-$7157   113.681539    $-$71.962325
# 9   WISE 0825+2805     126.280554      28.096545
# 10  WISE 1051$-$2138   162.875233    $-$21.650040
# 11  WISE 1055$-$1652   163.972546    $-$16.870930
# ...

# %%
df["Dec"] = df["Dec"].apply(lambda s: float(s.replace("$", "")))

# %%
df
# Out:
#                  Name          RA        Dec
# 0   WISE 0146+4234      26.735579  42.569408
# 1   WISE 0336$-$0143    54.020862  -1.732170
# 2   WISE 0350$-$5658    57.500996 -56.975638
# 3   WISE 0359$-$5401    59.891827 -54.032517
# 4   WISE 0410+1502      62.595853  15.044417
# 5   WISE 0535$-$7500    83.819477 -75.006740
# 6   WISE 0647$-$6232   101.846784 -62.542832
# 7   WISE 0713$-$2917   108.344414 -29.298188
# 8   WISE 0734$-$7157   113.681539 -71.962325
# 9   WISE 0825+2805     126.280554  28.096545
# 10  WISE 1051$-$2138   162.875233 -21.650040
# 11  WISE 1055$-$1652   163.972546 -16.870930
# 12  WISE 1206+8401     181.512553  84.019282
# 13  WISE 1318$-$1758   199.641070 -17.974002
# 14  WISE 1405+5534     211.322480  55.572793
# 15  WISE 1541$-$2250   235.464061 -22.840554
# 16  WISE 1639$-$6847   249.921736 -68.797280
# 17  WISE 1738+2732     264.648443  27.549315
# 18  WISE 1828+2650     277.130717  26.844012
# 19  WISE 2056+1459     314.121287  14.998666
# ...

# %%
for i in range(len(df)):
    plt.plot(df.iloc[i, 1], df.iloc[i, 2], 'ro')
    
plt.xlabel('RA')
plt.ylabel('Dec')
plt.show()
